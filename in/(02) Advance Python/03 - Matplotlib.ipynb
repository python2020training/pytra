# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from numpy.random import randn, randint, uniform, sample
import seaborn as sns
# %matplotlib inline 
# to keep the plot inline

np.set_printoptions(precision=4) # to set upto 4 decimal point
pd.options.display.max_rows = 5 # it will limit the row to 5 globally

# %%
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))
ts
# Out:
# 2019-06-07    0.285841
# 2019-06-08   -0.239431
#                 ...
# 2022-03-01   -0.862737
# 2022-03-02   -0.888245
# Freq: D, Length: 1000, dtype: float64

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])

df
# Out:
#                value
# 2019-06-07 -0.273508
# 2019-06-08 -1.652900
# ...              ...
# 2022-03-01  1.488194
# 2022-03-02 -0.188568
#
# [1000 rows x 1 columns]

# %%
df['value'] = df['value'].cumsum()  #comulative sum means sumession of previous no and current no
df
# Out:
#                value
# 2019-06-07 -0.273508
# 2019-06-08 -1.926408
# ...              ...
# 2022-03-01  5.759251
# 2022-03-02  5.570684
#
# [1000 rows x 1 columns]

# %%
ts = ts.cumsum()
ts
# Out:
# 2019-06-07     0.262204
# 2019-06-08     0.240259
#                 ...
# 2022-03-01   -54.772667
# 2022-03-02   -54.870561
# Freq: D, Length: 1000, dtype: float64

# %%
type(df), type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot(figsize=(10,5))   #figsize meanas below plot size

# %%
fig=plt.figure(figsize=(10,5))
plt.plot(ts)
fig.savefig('aaa.png')

# %%
plt.plot(ts)

# %%
df.plot()

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
ts.plot(kind = 'bar')

# %%
df = iris.drop(['species'], axis = 1)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# ..            ...          ...           ...          ...
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')

# %%
df.iloc[0].plot.bar() #same as above

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].plot(kind = 'bar')

# %%
df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df.head(10)
# Out:
#            a         b         c         d
# 0  -0.616318 -0.013061 -0.778177 -0.211223
# 1   0.951756  0.494079  0.984208  2.430210
# ..       ...       ...       ...       ...
# 8   0.373302 -0.377235 -1.955789 -0.995799
# 9  -0.248575  0.126526  1.124117 -0.765934
#
# [10 rows x 4 columns]

# %%
df.plot.bar()

# %%
df.plot(kind = 'bar')

# %%
df.plot.barh()  # it just move it in horizontal

# %%
iris=sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.plot.hist()

# %%
iris.plot(kind = 'hist')

# %%
iris.plot(kind = 'hist', stacked = False, bins = 100)

# %%
iris.plot(kind = 'hist', stacked = True, bins = 100)

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50, orientation = 'horizontal')

# %%
iris['sepal_width'].diff() #difference between previous and current one
# Out:
# 0      NaN
# 1     -0.5
#       ...
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 50)

# %%
df = iris.drop(['species'], axis = 1)
df.diff()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             NaN          NaN           NaN          NaN
# 1            -0.2         -0.5           0.0          0.0
# ..            ...          ...           ...          ...
# 148          -0.3          0.4           0.2          0.3
# 149          -0.3         -0.4          -0.3         -0.5
#
# [150 rows x 4 columns]

# %%
plt.style.use(['fast'])
df.diff().hist(color = 'b', alpha = 0.5, figsize=(10,10), zorder=3)

#alpha = colour density
#zorder = ??
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000013AAC28C2C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000013AAC4CBE88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000013AAD706E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000013AAD7408C8>]],
#       dtype=object)

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length');

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 190)

#s-size of the dot

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 50, C = 'sepal_width')

# it is same as scatter but hexa

# %%
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (5,5))

# %%
d = df.head(3).T
d # T- to Transpose
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (20, 20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000013AAE24C388>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000013AAE445948>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000013AAE40F148>],
#       dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 26, autopct = '%.2f')

#autopct - to show the percentage till 2 decimal point
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000013AAE52D6C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000013AAE55B088>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000013AAE52D448>],
#       dtype=object)

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df, figsize= (8,8), diagonal='kde', color = 'b')
plt.show()

# %%
ts.plot.kde()

#KDE Plot described as Kernel Density Estimate is used for visualizing the Probability Density of a continuous variable. It depicts the probability density at different values in a continuous variable. We can also plot a single graph for multiple samples which helps in more efficient data visualization.

# %%
from pandas.plotting import andrews_curves
andrews_curves(df, 'sepal_width')

# %%
ts.plot(style = 'r--', label = 'Series', legend = True)

# %%
df.plot(legend = True, figsize = (10, 5), logy = True)

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y = df.drop(['sepal_length', 'petal_length'], axis = 1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize = (16,7), secondary_y=True, ax = ax)

# %%
x.plot(figsize=(10,5), x_compat = True)

# %%
df.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000013AAED5D108>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000013AAEAACC88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000013AAEA7D988>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000013AAEC15388>],
#       dtype=object)

# %%
df.plot(subplots = True, sharex = False, layout = (2,3), figsize = (16,8))
plt.tight_layout()
